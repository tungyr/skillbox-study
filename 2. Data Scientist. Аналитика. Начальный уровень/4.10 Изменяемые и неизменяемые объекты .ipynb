# %%
my_list = [1, 2, 3, 'apple', ['a', 'b', 'c']]

# %%
second_list = my_list

# %%
my_list.append(100)

# %%
my_list
# Out:
# [1, 2, 3, 'apple', ['a', 'b', 'c'], 100]

# %%
second_list
# Out:
# [1, 2, 3, 'apple', ['a', 'b', 'c'], 100]

# %%
car = 'Lacetti'

# %%
car.replace('L', 'R')
# Out:
# 'Racetti'

# %%
car
# Out:
# 'Lacetti'

# %%
my_list[-1] = 222

# %%
my_list
# Out:
# [1, 2, 3, 'apple', ['a', 'b', 'c'], 222]

# %%
big_list = [[], []]

# %%
big_list = big_list * 2

# %%
big_list
# Out:
# [[], [], [], []]

# %%
big_list[0].append(2)

# %%
big_list
# Out:
# [[2], [], [2], []]

# %%
big_list[1].append(3)

# %%
big_list
# Out:
# [[2], [3], [2], [3]]

# %%
id(big_list[0])
# print(big_list[0])
# Out:
# 1454912647368

# %%
id(big_list[2])
# print((big_list[2]))
# Out:
# 1454912647368

# %%
 valve = 42

# %%
id(valve)
# Out:
# 140722165884592

# %%
mass = valve

# %%
id(mass)
# Out:
# 140722165884592

# %%
mass = mass + 1

# %%
id(mass)
# Out:
# 140722165884624

# %%
mass = mass - 1

# %%
id(mass)
# Out:
# 140722165884592

# %%
id(car)
# Out:
# 1454914042608

# %%
my_car = car

# %%
my_car = my_car + 'Chevrolet'

# %%
my_car
# Out:
# 'LacettiChevrolet'

# %%
car
# Out:
# 'Lacetti'

# %%
id(my_car)
# Out:
# 1454914132448

# %%
id(car)
# Out:
# 1454914042608
